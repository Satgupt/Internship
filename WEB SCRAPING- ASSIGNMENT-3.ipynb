# %%
import selenium
from selenium import webdriver
import pandas as pd
import time

# %% [raw]
# Q1. Write a python program which searches all the product under a particular product vertical from www.amazon.in. The product verticals to be searched will be taken as input from user. For e.g. If user input is ‘guitar’. Then search for guitars.

# %%
driver = webdriver.Chrome(r'C:\Users\welcome\Desktop\chromedriver_win32\chromedriver.exe')
# Out:
# <ipython-input-2-53e154298f5b>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\welcome\Desktop\chromedriver_win32\chromedriver.exe')

# %%
# Getting url
url= "https://www.amazon.in/"
driver.get(url)

# %%
search=driver.find_element_by_id("twotabsearchtextbox")
search.send_keys('guitars')
# Out:
# <ipython-input-4-950f649c9255>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search=driver.find_element_by_id("twotabsearchtextbox")

# %%
search_btn=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")
search_btn.click()
# Out:
# <ipython-input-5-e0100c735a8f>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn=driver.find_element_by_xpath("/html/body/div[1]/header/div/div[1]/div[2]/div/form/div[3]/div/span/input")

# %% [markdown]
# 1- In the above question, now scrape the following details of each product listed in first 3 pages of your search results and save it in a data frame and csv. In case if any product vertical has less than 3 pages in search results then scrape all the products available under that product vertical. Details to be scraped are: "Brand Name", "Name of the Product", "Rating", "No. of Ratings", "Price", "Return/Exchange", "Expected Delivery", "Availability", "Other Details" and “Product URL”. In case, if any of the details are missing for any of the product then replace it by “-“.

# %%
# Scraping urls for each url of product
URL=[]
for i in range(1,4):
    url_tags=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
    for j in url_tags:
        URL.append(j.get_attribute("href"))
    nxt_button=driver.find_elements_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')
     #scraping the list of buttons from the page
    try:
        driver.get(nxt_button[1].get_attribute('href'))       #getting the link from the list for next page
    except:
        driver.get(nxt_button[0].get_attribute('href'))
# Out:
# <ipython-input-6-b746346a697a>:4: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   url_tags=driver.find_elements_by_xpath("//a[@class='a-link-normal a-text-normal']")
# <ipython-input-6-b746346a697a>:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   nxt_button=driver.find_elements_by_xpath('//a[@class="s-pagination-item s-pagination-next s-pagination-button s-pagination-separator"]')

# %%
len(URL)
# Out:
# 3

# %%
brand=[]
product_name=[]
price=[]
prod_url=[]
Return=[]
exp_delivery=[]
availability=[]

# %%
for i in range(len(URL)):
    driver.get(URL[i])
    time.sleep(3)
    prod_url.append(URL[i])
    try:
        brand_tag= driver.find_element_by_xpath("//span[@class='a-size-base']")
        brand.append(brand_tag.text)
    except:
        brand.append("-")
    try:
        name= driver.find_element_by_id("productTitle")
        product_name.append(name.text)
    except:
        product_name.append("-")
   
    try:
        price_tag= driver.find_element_by_id("priceblock_ourprice")
        price.append(price_tag.text)
    except:
        price.append("-")
    try:
        retrn= driver.find_element_by_xpath("//a[@class='a-size-small a-link-normal a-text-normal']")
        Return.append(retrn.text)
    except:
        Return.append("-")
    try:
        deliver= driver.find_element_by_id("ddmDeliveryMessage")
        exp_delivery.append(deliver.text)
    except:
        exp_delivery.append("-")
    try:
        avail= driver.find_element_by_id("availability")
        availability.append(avail.text)
    except:
        availability.append("-")
# Out:
# <ipython-input-10-1cc4a539e382>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   brand_tag= driver.find_element_by_xpath("//span[@class='a-size-base']")
# <ipython-input-10-1cc4a539e382>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name= driver.find_element_by_id("productTitle")
# <ipython-input-10-1cc4a539e382>:17: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   price_tag= driver.find_element_by_id("priceblock_ourprice")
# <ipython-input-10-1cc4a539e382>:22: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   retrn= driver.find_element_by_xpath("//a[@class='a-size-small a-link-normal a-text-normal']")
# <ipython-input-10-1cc4a539e382>:27: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   deliver= driver.find_element_by_id("ddmDeliveryMessage")
# <ipython-input-10-1cc4a539e382>:32: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   avail= driver.find_element_by_id("availability")

# %%
## Creating dataframe
prod_details=pd.DataFrame()
prod_details["Brand"]=brand
prod_details["Product_Name"]=product_name
prod_details["Availability"]=availability
prod_details["Expected_Delivery"]=exp_delivery
prod_details["Return"]=Return
prod_details["Price"]=price
prod_details["Product Url"]=prod_url
prod_details.head()
# Out:
#        Brand                                       Product_Name Availability  \
# 0  Quantity:  Kadence Guitar Acoustica Series, Electric Acou...
# 1  Quantity:  Kadence Guitar Acoustica Series, Electric Acou...
# 2  Quantity:  Kadence Guitar Acoustica Series, Electric Acou...
#
#                    Expected_Delivery           Return Price  \
# 0  FREE delivery: Saturday, March 12  Pay on Delivery     -
# 1  FREE delivery: Saturday, March 12  Pay on Delivery     -
# 2  FREE delivery: Saturday, March 12  Pay on Delivery     -
#
#                                          Product Url
# 0  https://aax-eu.amazon.in/x/c/Qi3-3LB_eMV-YRwRA...
# 1  https://aax-eu.amazon.in/x/c/QmEoySEEEKR50GGjs...
# 2  https://aax-eu.amazon.in/x/c/Qr_oKBHoKv4eFf7W6...

# %%
# Saving File
prod_details.to_csv("Product_Details")

# %% [markdown]
# 3. Write a python program to access the search bar and search button on images.google.com and scrape 10 images each for keywords ‘fruits’, ‘cars’ and ‘Machine Learning’, ‘Guitar’, ‘Cakes’.

# %%
# Function Definition
def google_img(url):
    driver=webdriver.Chrome(r'C:\Users\welcome\Desktop\chromedriver_win32\chromedriver.exe')
    fruits=[]
    cars=[]
    machine_learning=[]
    guitar=[]
    cakes=[]
#extracting fruits data
    driver.get(url)
    search_field_items=driver.find_element_by_xpath("//div[@class='a4bIc']/input")
    search_field_items.send_keys("fruits")
    search_button=driver.find_element_by_xpath("//button[@class='Tg7LZd']")
    search_button.click()
    for i in range(0,3):
        url_tags=driver.find_elements_by_xpath("//div[@class='islrc']//div[@class='isv-r PNCib MSM1fd BUooTd']//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']")
        for i in url_tags:
            fruits.append(i.get_attribute('href'))   
        time.sleep(2)
#extracting car image data        
    driver.get(url)
    search_field_items=driver.find_element_by_xpath("//div[@class='a4bIc']/input")
    search_field_items.send_keys("cars")
    search_button=driver.find_element_by_xpath("//button[@class='Tg7LZd']")
    search_button.click()
    for i in range(0,3):
        url_tags=driver.find_elements_by_xpath("//div[@class='islrc']//div[@class='isv-r PNCib MSM1fd BUooTd']//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']")
        for i in url_tags:
            cars.append(i.get_attribute('href'))   
        time.sleep(2)
#extracting machine learning imgae data        
    driver.get(url)
    search_field_items=driver.find_element_by_xpath("//div[@class='a4bIc']/input")
    search_field_items.send_keys("machine learning")
    search_button=driver.find_element_by_xpath("//button[@class='Tg7LZd']")
    search_button.click()
    for i in range(0,3):
        url_tags=driver.find_elements_by_xpath("//div[@class='islrc']//div[@class='isv-r PNCib MSM1fd BUooTd']//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']")
        for i in url_tags:
            machine_learning.append(i.get_attribute('href'))   
            
#extracting Guitar imgae data        
    driver.get(url)
    search_field_items=driver.find_element_by_xpath("//div[@class='a4bIc']/input")
    search_field_items.send_keys("Guitar")
    search_button=driver.find_element_by_xpath("//button[@class='Tg7LZd']")
    search_button.click()
    for i in range(0,3):
        url_tags=driver.find_elements_by_xpath("//div[@class='islrc']//div[@class='isv-r PNCib MSM1fd BUooTd']//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']")
        for i in url_tags:
            guitar.append(i.get_attribute('href'))   
        
#extracting Cakes imgae data        
    driver.get(url)
    search_field_items=driver.find_element_by_xpath("//div[@class='a4bIc']/input")
    search_field_items.send_keys("cakes")
    search_button=driver.find_element_by_xpath("//button[@class='Tg7LZd']")
    search_button.click()
    for i in range(0,3):
        url_tags=driver.find_elements_by_xpath("//div[@class='islrc']//div[@class='isv-r PNCib MSM1fd BUooTd']//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']")
        for i in url_tags:
            cakes.append(i.get_attribute('href'))         
    
        
    print('Length of the list are ==>>',len(fruits),len(cars),len(machine_learning),len(guitar),len(cakes))
    google_image=pd.DataFrame({'Fruits':fruits[:100],
                           'cars':cars[:100],
                            'machine_learning':machine_learning[:100],
                            'guitar':guitar[:100],
                            'cakes':cakes[:100]})
                            
    print(google_image)
    google_image.to_csv('google_image.csv', index = False)
    
    
# Calling Function
google_img('https://images.google.com/?gws_rd=ssl')
# Out:
# <ipython-input-100-00fd10efd555>:3: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver=webdriver.Chrome(r'C:\Users\welcome\Desktop\chromedriver_win32\chromedriver.exe')
# <ipython-input-100-00fd10efd555>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_field_items=driver.find_element_by_xpath("//div[@class='a4bIc']/input")
# <ipython-input-100-00fd10efd555>:13: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button=driver.find_element_by_xpath("//button[@class='Tg7LZd']")
# <ipython-input-100-00fd10efd555>:16: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   url_tags=driver.find_elements_by_xpath("//div[@class='islrc']//div[@class='isv-r PNCib MSM1fd BUooTd']//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']")
# <ipython-input-100-00fd10efd555>:22: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_field_items=driver.find_element_by_xpath("//div[@class='a4bIc']/input")
# <ipython-input-100-00fd10efd555>:24: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button=driver.find_element_by_xpath("//button[@class='Tg7LZd']")
# <ipython-input-100-00fd10efd555>:27: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   url_tags=driver.find_elements_by_xpath("//div[@class='islrc']//div[@class='isv-r PNCib MSM1fd BUooTd']//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']")
# <ipython-input-100-00fd10efd555>:33: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_field_items=driver.find_element_by_xpath("//div[@class='a4bIc']/input")
# <ipython-input-100-00fd10efd555>:35: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button=driver.find_element_by_xpath("//button[@class='Tg7LZd']")
# <ipython-input-100-00fd10efd555>:38: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   url_tags=driver.find_elements_by_xpath("//div[@class='islrc']//div[@class='isv-r PNCib MSM1fd BUooTd']//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']")
# <ipython-input-100-00fd10efd555>:44: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_field_items=driver.find_element_by_xpath("//div[@class='a4bIc']/input")
# <ipython-input-100-00fd10efd555>:46: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button=driver.find_element_by_xpath("//button[@class='Tg7LZd']")
# <ipython-input-100-00fd10efd555>:49: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   url_tags=driver.find_elements_by_xpath("//div[@class='islrc']//div[@class='isv-r PNCib MSM1fd BUooTd']//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']")
# <ipython-input-100-00fd10efd555>:55: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_field_items=driver.find_element_by_xpath("//div[@class='a4bIc']/input")
# <ipython-input-100-00fd10efd555>:57: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_button=driver.find_element_by_xpath("//button[@class='Tg7LZd']")
# <ipython-input-100-00fd10efd555>:60: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   url_tags=driver.find_elements_by_xpath("//div[@class='islrc']//div[@class='isv-r PNCib MSM1fd BUooTd']//a[@class='VFACy kGQAp sMi44c lNHeqe WGvvNb']")
# Length of the list are ==>> 144 144 144 141 144
#                                                Fruits  \
# 0   https://www.amazon.in/Learning-Educational-Hom...
# 1   https://www.goodhousekeeping.com/health/diet-n...
# 2   https://www.healthyeating.org/nutrition-topics...
# 3   https://www.amazon.in/Fruits-Chart-Vidya-Chitr...
# 4    https://in.pinterest.com/pin/641340803167435998/
# ..                                                ...
# 95  https://www.health.harvard.edu/nutrition/how-m...
# 96  https://www.amazon.in/Learning-Educational-Hom...
# 97  https://www.goodhousekeeping.com/health/diet-n...
# 98  https://www.healthyeating.org/nutrition-topics...
# 99  https://www.amazon.in/Fruits-Chart-Vidya-Chitr...
#
#                                                  cars  \
# 0   https://www.forbes.com/sites/jimgorzelany/2019...
# 1   https://www.motor1.com/car-lists/most-expensiv...
# 2      https://www.motor1.com/car-lists/coolest-cars/
# 3   https://www.mercedes-benz.com/en/vehicles/pass...
# 4       https://en.wikipedia.org/wiki/Cars_%28film%29
# ..                                                ...
# 95  https://www.roadandtrack.com/car-culture/buyin...
# 96  https://www.forbes.com/sites/jimgorzelany/2019...
# 97  https://www.motor1.com/car-lists/most-expensiv...
# 98     https://www.motor1.com/car-lists/coolest-cars/
# 99  https://www.mercedes-benz.com/en/vehicles/pass...
#
#                                      machine_learning  \
# 0   https://towardsdatascience.com/machine-learnin...
# 1   https://www.forbes.com/sites/tomtaulli/2019/03...
# 2   https://www.forbes.com/sites/kalevleetaru/2019...
# 3   https://towardsdatascience.com/artificial-inte...
# 4   https://www.atriainnovation.com/en/machine-lea...
# ..                                                ...
# 95  https://portswigger.net/daily-swig/deepsloth-r...
# 96  https://towardsdatascience.com/machine-learnin...
# 97  https://www.forbes.com/sites/tomtaulli/2019/03...
# 98  https://www.forbes.com/sites/kalevleetaru/2019...
# 99  https://towardsdatascience.com/artificial-inte...
#
#                                                guitar  \
# 0                https://en.wikipedia.org/wiki/Guitar
# 1   https://yamahamusicstore.in/f280-natural-acous...
# 2   https://www.amazon.com/Yamaha-FG800-Solid-Acou...
# 3   https://www.amazon.in/Yamaha-FS100C-Acoustic-G...
# 4           https://www.britannica.com/summary/guitar
# ..                                                ...
# 95  https://yamahamusicstore.in/f280-natural-acous...
# 96  https://www.amazon.com/Yamaha-FG800-Solid-Acou...
# 97  https://www.amazon.in/Yamaha-FS100C-Acoustic-G...
# 98          https://www.britannica.com/summary/guitar
# 99  https://online.berklee.edu/takenote/acoustic-g...
#
#                                                 cakes
# 0   https://www.landolakes.com/recipe/21329/rainbo...
# 1   https://sallysbakingaddiction.com/triple-choco...
# 2         https://www.youtube.com/watch?v=ce3sMr_fkFA
# 3                  https://en.wikipedia.org/wiki/Cake
# 4     https://cakewhiz.com/best-birthday-cake-recipe/
# ..                                                ...
# 95  https://www.tripadvisor.in/Restaurant_Review-g...
# 96  https://www.landolakes.com/recipe/21329/rainbo...
# 97  https://sallysbakingaddiction.com/triple-choco...
# 98        https://www.youtube.com/watch?v=ce3sMr_fkFA
# 99                 https://en.wikipedia.org/wiki/Cake
#
# [100 rows x 5 columns]

# %%
driver.close()

# %% [markdown]
# 4. Write a python program to search for a smartphone(e.g.: Oneplus Nord, pixel 4A, etc.) on www.flipkart.com and scrape following details for all the search results displayed on 1st page. Details to be  scraped: “Brand Name”, “Smartphone name”, “Colour”, “RAM”, “Storage(ROM)”, “Primary Camera”,  “Secondary Camera”, “Display Size”, “Battery Capacity”, “Price”, “Product URL”. Incase if any of the  details is missing then replace it by “- “. Save your results in a dataframe and CSV.

# %%
driver = webdriver.Chrome(r'C:\Users\welcome\Desktop\chromedriver_win32\chromedriver.exe')
# Out:
# <ipython-input-17-53e154298f5b>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\welcome\Desktop\chromedriver_win32\chromedriver.exe')

# %%
url="https://www.flipkart.com"
driver.get(url)

# %%
search=driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")
search.send_keys("Oneplus Nord,pixel 4A")
# Out:
# <ipython-input-19-5bbf08fe47bc>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search=driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/div/input")

# %%
btn= driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")
btn.click()
# Out:
# <ipython-input-21-0d8998f94d55>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   btn= driver.find_element_by_xpath("/html/body/div[1]/div/div[1]/div[1]/div[2]/div[2]/form/div/button")

# %%
# Scraping urls for each url of product
urls=[]
url_tags=driver.find_elements_by_xpath("//a[@class='_1fQZEK']")
for j in url_tags:
    urls.append(j.get_attribute("href"))
# Out:
# <ipython-input-22-e7b03b779769>:3: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   url_tags=driver.find_elements_by_xpath("//a[@class='_1fQZEK']")

# %%
name=[]
color=[]
ram=[]
rom=[]
pri_cam=[]
sec_cam=[]
disp_size=[]
disp_res=[]
processor=[]
battery=[]
price=[]

# %%
name=[]
color=[]
ram=[]
rom=[]
pri_cam=[]
sec_cam=[]
disp_size=[]
#disp_res=[]
#processor=[]
battery=[]
price=[]
for i in range(len(urls)):
    driver.get(urls[i])
    time.sleep(5)
    btn= driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']")
    btn.click()
    try:
        color_tag= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[1]/table/tbody/tr[4]/td[2]/ul/li")
        color.append(color_tag.text)
    except:
        color.append("-")
    try:
        name_tag= driver.find_element_by_xpath("//span[@class='B_NuCI']")
        name.append(name_tag.text)
    except:
        name.append("-")
    try:
        disp_tag= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[2]/table/tbody/tr[1]/td[2]/ul/li")
        disp_size.append(disp_tag.text)
    except:
        disp_size.append("-")
    #try:
        #disp_tags= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[2]/table/tbody/tr[2]/td[2]/ul/li")
        #disp_res.append(disp_tags.text)
    #except:
        #disp_res.append("-")
    try:
        price_tag= driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
        price.append(price_tag.text)
    except:
        price.append("-")
    try:
        cam_tag= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[2]/td[2]/ul/li")
        pri_cam.append(cam_tag.text)
    except:
        pri_cam.append("-")
    try:
        cam_tags= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[5]/td[2]/ul/li")
        sec_cam.append(cam_tags.text)
    except:
        sec_cam.append("-")
    #try:
        #proc= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[5]")
        #processor.append(proc.text)
    #except:
        #processor.append("-")
    try:
        btry= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[4]")
        battery.append(btry.text)
    except:
        battery.append("-")
    try:
        mem= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[4]/table/tbody/tr[2]/td[2]")
        ram.append(mem.text)
    except:
        ram.append("-")
    try:
        memr= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[4]/table/tbody/tr[1]/td[2]/ul/li")
        rom.append(memr.text)
    except:
        rom.append("-")
# Out:
# <ipython-input-24-0f822f6b492a>:15: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   btn= driver.find_element_by_xpath("//button[@class='_2KpZ6l _1FH0tX']")
# <ipython-input-24-0f822f6b492a>:18: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   color_tag= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[1]/table/tbody/tr[4]/td[2]/ul/li")
# <ipython-input-24-0f822f6b492a>:23: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   name_tag= driver.find_element_by_xpath("//span[@class='B_NuCI']")
# <ipython-input-24-0f822f6b492a>:28: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   disp_tag= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[2]/table/tbody/tr[1]/td[2]/ul/li")
# <ipython-input-24-0f822f6b492a>:38: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   price_tag= driver.find_element_by_xpath("//div[@class='_30jeq3 _16Jk6d']")
# <ipython-input-24-0f822f6b492a>:43: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   cam_tag= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[2]/td[2]/ul/li")
# <ipython-input-24-0f822f6b492a>:48: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   cam_tags= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[5]/table/tbody/tr[5]/td[2]/ul/li")
# <ipython-input-24-0f822f6b492a>:58: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   btry= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[8]/div[1]/div/div[2]/ul/li[4]")
# <ipython-input-24-0f822f6b492a>:63: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   mem= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[4]/table/tbody/tr[2]/td[2]")
# <ipython-input-24-0f822f6b492a>:68: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   memr= driver.find_element_by_xpath("/html/body/div[1]/div/div[3]/div[1]/div[2]/div[9]/div[4]/div/div[2]/div[1]/div[4]/table/tbody/tr[1]/td[2]/ul/li")

# %%
## Creating dataframe
prod_detail=pd.DataFrame()
prod_detail["Product_Name"]=name
prod_detail["Colour"]=color
prod_detail["RAM"]=ram
prod_detail["ROM"]=rom
prod_detail["Primary Camera"]=pri_cam
prod_detail["Secondary Camera"]=sec_cam
prod_detail["Display Size"]=disp_size
#prod_detail["Display Resolution"]=disp_res
prod_detail["Battery"]=battery

prod_detail["Price"]=price

#prod_detail["Processor"]=processor


prod_detail["Product URL"]=url
prod_detail.head()
# Out:
#                                         Product_Name Colour RAM ROM  \
# 0      LAVA Pixel V2 Plus (Black, 16 GB)  (2 GB RAM)      -   -   -
# 1  SAMSUNG Galaxy S10 Plus (Ceramic White, 1 TB) ...      -   -   -
# 2         ringme Reno Plus (Blue, 16 GB)  (2 GB RAM)      -   -   -
# 3          ringme Reno Plus (Red, 16 GB)  (2 GB RAM)      -   -   -
# 4  KARBONN Titanium S9 plus (Blue, 32 GB)  (3 GB ...      -   -   -
#
#   Primary Camera Secondary Camera Display Size Battery      Price  \
# 0              -                -            -       -     ₹6,199
# 1              -                -            -       -  ₹1,17,990
# 2              -                -            -       -     ₹4,990
# 3              -                -            -       -     ₹5,145
# 4              -                -            -       -     ₹5,999
#
#                 Product URL
# 0  https://www.flipkart.com
# 1  https://www.flipkart.com
# 2  https://www.flipkart.com
# 3  https://www.flipkart.com
# 4  https://www.flipkart.com

# %%
# Saving File
prod_detail.to_csv("Mobile_Details")

# %% [markdown]
# 5. Write a program to scrap geospatial coordinates (latitude, longitude) of a city searched on google maps.

# %%
url="https://www.google.com/maps"
driver.get(url)

# %%
search= driver.find_element_by_xpath("//input[@class='tactile-searchbox-input']")
search.send_keys('Jhansi')
# Out:
# <ipython-input-28-55cb86d5edf7>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search= driver.find_element_by_xpath("//input[@class='tactile-searchbox-input']")

# %%
import re

# %%
try:

    url_string = driver.current_url

    print("URL Extracted: ", url_string)

    lat_lng = re.findall(r'@(.*)data',url_string)

    if (len(lat_lng)>0):

        lat_lng_list = lat_lng[0].split(",")

        if len(lat_lng_list)>=2:

            lat = lat_lng_list[0]

            lng = lat_lng_list[1]

        print("Latitude = {}, Longitude = {}".format(lat, lng))



except Exception as e:

        print("Error: ", str(e))
# Out:
# URL Extracted:  https://www.google.com/maps/@27.141237,80.8833819,7z

# %% [markdown]
#  6. Write a program to scrap details of all the funding deals for second quarter (i.e Jan 21 – March 21) from trak.in.

# %%
url= "https://www.trak.in"
driver.get(url)

# %%
more_btn=driver.find_element_by_xpath("//li[@class='bs-pretty-tabs-container menu-item-has-children menu-item better-anim-fade bsm-leave']")
more_btn.click()

btn=driver.find_element_by_xpath("//li[@class='menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page better-anim-fade menu-item-51510']")
btn.click()
# Out:
# <ipython-input-51-dca9b9060f20>:1: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   more_btn=driver.find_element_by_xpath("//li[@class='bs-pretty-tabs-container menu-item-has-children menu-item better-anim-fade bsm-leave']")
# <ipython-input-51-dca9b9060f20>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   btn=driver.find_element_by_xpath("//li[@class='menu-have-icon menu-icon-type-fontawesome menu-item menu-item-type-post_type menu-item-object-page better-anim-fade menu-item-51510']")

# %%
fund_dict = {}
fund_dict['Date'] = []
fund_dict['Startup Name'] = []
fund_dict['Industry/Vertical'] = []
fund_dict['Sub-Vertical'] = []
fund_dict['Location'] = []
fund_dict['Investor'] = []
fund_dict['Investment Type'] = []
fund_dict['Amount(in USD)'] = []

# %%
for i in range(54,57):
    driver.find_element_by_xpath('//div[@id="tablepress-{}_wrapper"]/div/label/select/option[4]'.format(i)).click()

    # Date
    dt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
    for d in dt:
        fund_dict['Date'].append(d.text)

    # Startup Name
    sn = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
    for n in sn:
        fund_dict['Startup Name'].append(n.text)
    
    # Industry/Vertical
    ind = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
    for n in ind:
        fund_dict['Industry/Vertical'].append(n.text)
    
    # Sub-Vertical
    sv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
    for s in sv:
        fund_dict['Sub-Vertical'].append(s.text)

    # Location
    loc = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
    for l in loc:
        fund_dict['Location'].append(l.text)
    
    # Investor
    inv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
    for n in inv:
        fund_dict['Investor'].append(n.text)
    
    # Investment Type
    invt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
    for n in invt:
        fund_dict['Investment Type'].append(n.text)
    
    # Amount
    amt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
    for a in amt:
        fund_dict['Amount(in USD)'].append(a.text)
    
fund_df = pd.DataFrame(fund_dict)
fund_df
# Out:
# <ipython-input-53-48cc2f98695b>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//div[@id="tablepress-{}_wrapper"]/div/label/select/option[4]'.format(i)).click()
# <ipython-input-53-48cc2f98695b>:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[2]'.format(i))
# <ipython-input-53-48cc2f98695b>:10: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   sn = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[3]'.format(i))
# <ipython-input-53-48cc2f98695b>:15: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   ind = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[4]'.format(i))
# <ipython-input-53-48cc2f98695b>:20: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   sv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[5]'.format(i))
# <ipython-input-53-48cc2f98695b>:25: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   loc = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[6]'.format(i))
# <ipython-input-53-48cc2f98695b>:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   inv = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[7]'.format(i))
# <ipython-input-53-48cc2f98695b>:35: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   invt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[8]'.format(i))
# <ipython-input-53-48cc2f98695b>:40: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   amt = driver.find_elements_by_xpath('//table[@id="tablepress-{}"]/tbody/tr/td[9]'.format(i))
#           Date            Startup Name       Industry/Vertical  \
# 0   15/01/2021         Digit Insurance      Financial Services
# 1   28/01/2021  Bombay Shaving Company  Consumer Goods Company
# 2   19/01/2021                  DeHaat        AgriTech Startup
# 3   19/01/2021               Darwinbox                    SaaS
# 4   18/01/2021                   mfine     Health Tech Startup
# 5   18/01/2021                   Udayy                  EdTech
# 6   11/01/2021           True Elements            Food Startup
# 7   13/01/2021                   Saveo          B2B E-commerce
# 8   11/02/2021                Doubtnut                Edu Tech
# 9   22/02/2021                  Zomato             Hospitality
# 10  19/02/2021               Fingerlix             Hospitality
# 11  17/02/2021                   Zolve                 FinTech
# 12  15/02/2021               KreditBee                 Finance
# 13  12/02/2021               Pepperfry              E-commerce
# 14  12/02/2021                 Grofers              E-Commerce
# 15  09/02/2021                 Nothing              Technology
# 16  09/02/2021             SplashLearn                  EdTech
# 17  04/03/2021               DealShare              E-commerce
# 18  31/03/2021                Uniphore              Technology
# 19  30/03/2021                   Dunzo              E-commerce
# 20  30/03/2021                  BYJU’S                Edu-tech
# 21  23/03/2021             SkilloVilla                Edu-tech
# 22  25/03/2021                CityMall              E-commerce
# 23  26/03/2021                   DotPe                 FinTech
#
#                                          Sub-Vertical           Location  \
# 0                                  Insurance Services          Bengaluru
# 1       Shave care, beard care, and skincare products          New Delhi
# 2   online marketplace for farm products and services              Patna
# 3                                             HR Tech             Mumbai
# 4                  AI-powered telemedicine mobile app          Bengaluru
# 5      Online learning platform for kids in class 1-5            Gurgaon
# 6                       Whole Food plant based Nashta               Pune
# 7                                          Pharmacies          Bengaluru
# 8                                 E-Learning Platform            Gurgaon
# 9                       Online Food Delivery Platform            Gurgaon
# 10                      Semi-cooked food delivery app             Mumbai
# 11                             Global Neobank Venture             Mumbai
# 12                           Digital lending platform          Bengaluru
# 13                        Multi-brand furniture brand             Mumbai
# 14                                 Online supermarket            Gurgaon
# 15                        Consumer Technology Venture             London
# 16                      Game-based learning programme            Gurgaon
# 17                           Online shopping platform  Jaipur, Rajasthan
# 18            Conversational Service Automation (CSA)          Palo Alto
# 19                           Hyper-local delivery app          Bengaluru
# 20                                    Online tutoring          Bengaluru
# 21                Career and job-oriented upskilling.          Bengaluru
# 22       Social ecommerce and online grocery platform            Gurgaon
# 23  Commerce and payments platform to offline ente...            Gurgaon
#
#                                              Investor Investment Type  \
# 0    A91 Partners, Faering Capital, TVS Capital Funds         Venture
# 1                                   Reckitt Benckiser         Venture
# 2                                     Prosus Ventures        Series C
# 3                                 Salesforce Ventures            Seed
# 4                          Heritas Capital Management   Venture Round
# 5                                     Sequoia Capital    Seed Funding
# 6                               SIDBI Venture Capital          Series
# 7           Matrix Partners India, RTP Global, others            Seed
# 8   SIG Global, Sequoia Capital, WaterBridge Ventu...        Series B
# 9                                  Tiger Global, Kora         Venture
# 10           Rhodium Trust, Accel Partners and Swiggy        Series C
# 11     Accel Partners and Lightspeed Venture Partners            Seed
# 12  Azim Premji’s PremjiInvest and South Korea’s M...        Series C
# 13                                    InnoVen Capital  Debt Financing
# 14                         SoftBank Vision Fund (SVF)     Unspecified
# 15                                                 GV        Series A
# 16                                       Owl Ventures        Series C
# 17                                    Innoven Capital  Debt Financing
# 18                          Sorenson Capital Partners        Series D
# 19                          Krishtal Advisors Pte Ltd        Series E
# 20         MC Global Edtech, B Capital, Baron, others        Series F
# 21                              Titan Capital, others            Seed
# 22                                     Accel Partners        Series A
# 23                                               PayU        Series A
#
#    Amount(in USD)
# 0     1,80,00,000
# 1    6,172,258.50
# 2      30,000,000
# 3      15,000,000
# 4      16,000,000
# 5      15,000,000
# 6     100,000,000
# 7       4,000,000
# 8       2,500,000
# 9     250,000,000
# 10   2,747,045.20
# 11    1,50,00,000
# 12     75,000,000
# 13      4,773,958
# 14     55,000,000
# 15     15,000,000
# 16     18,000,000
# 17    250,000,000
# 18    140,000,000
# 19      8,000,000
# 20    460,000,000
# 21    300,000,000
# 22     11,000,000
# 23     27,500,000

# %% [markdown]
# Q7. Write a program to scrap all the available details of top 10 gaming laptops from digit.in.

# %%
url= "https://www.digit.in"
driver.get(url)

# %%
#clickng on top 10 option 
top_10=driver.find_element_by_xpath("//div[@class='menu']/ul/li[4]/a")
top_10.click()

#clicking on laptops option
laptops=driver.find_element_by_xpath("//div[@class='categoty_list']/button[2]")
laptops.click()

#best gaming laptops link
best_gaming=driver.find_element_by_xpath("//div[@id='laptops']/div[3]/a")
driver.get(best_gaming.get_attribute('href'))

#intialising lists
name = []
price = []
OS = []
display = []
HDD = []
RAM = []
weight = []
dimension = []
GPU = []

#names
names=driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
for i in names:
    name.append(i.text)
    
#os
os=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[1]/div/div")
for i in os:
    OS.append(i.text)
    
#display
displays=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[2]/div/div")
for i in displays:
    display.append(i.text)
    

#memory
memories=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[1]")#list of specificaion name
memories_spec=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")#values of specifiations 
for i in range(len(memories)):
        if memories[i].text=='Memory':
            HDD.append(memories_spec[i].text.split('/')[0])
            RAM.append(memories_spec[i].text.split('/')[1])
        else:
            HDD.append('No details available')#append no details as value for memory is missing in some of the laptops
            RAM.append('No details available')#append no details as value for memory is missing in some of the laptops

#weight
weights=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[1]")#list of specificaion name
weight_spec=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[3]")#values of specifiations
for i in range(len(weights)):
        if weights[i].text=='Weight':
            weight.append(weight_spec[i].text)
        
#dimension
dimension=[]
dims=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[1]")#list of specificaion name
dims_spec=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[3]")#values of specifiations
for i in range(len(dims)):
        if dims[i].text=='Dimension':
            dimension.append(dims_spec[i].text)

#graphical processor
GPUs=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[1]")#list of specificaion name
GPUs_spec=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[3]")#values of specifiations
for i in range(len(GPUs)):
        if GPUs[i].text=='Graphics Processor':
            GPU.append(GPUs_spec[i].text)
        
full_specs=[]
urls=driver.find_elements_by_xpath("//div[@class='full-specs']/span")#getting the url of full specs links
for i in urls:
    if i.get_attribute('data-href'):
        full_specs.append(i.get_attribute('data-href'))
    
for i in full_specs:#iterating throug every laptops full specs' page
    driver.get(i)
    try:
        prices=driver.find_element_by_xpath("/html/body/div[3]/div[2]/div[3]/div[3]/div[4]/div/h2/strong")
        price.append(prices.text)
    except NoSuchElementException:#exception handling for no price details
        price.append("No details available")
        
df=pd.DataFrame({"Name":name,
                "Price":price,
                "OS":OS,
                "Display":display,
                "HDD":HDD,
                 "RAM":RAM,
                "weight":weight,
                "Dimension":dimension,
                "Graphical processor":GPU})
df
# Out:
# <ipython-input-89-32e65d834f5c>:2: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   top_10=driver.find_element_by_xpath("//div[@class='menu']/ul/li[4]/a")
# <ipython-input-89-32e65d834f5c>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   laptops=driver.find_element_by_xpath("//div[@class='categoty_list']/button[2]")
# <ipython-input-89-32e65d834f5c>:10: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   best_gaming=driver.find_element_by_xpath("//div[@id='laptops']/div[3]/a")
# <ipython-input-89-32e65d834f5c>:25: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   names=driver.find_elements_by_xpath("//div[@class='right-container']/div/a/h3")
# <ipython-input-89-32e65d834f5c>:30: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   os=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[1]/div/div")
# <ipython-input-89-32e65d834f5c>:35: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   displays=driver.find_elements_by_xpath("//div[@class='product-detail']/div/ul/li[2]/div/div")
# <ipython-input-89-32e65d834f5c>:41: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   memories=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[1]")#list of specificaion name
# <ipython-input-89-32e65d834f5c>:42: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   memories_spec=driver.find_elements_by_xpath("//div[@class='Spcs-details'][1]/table/tbody/tr[6]/td[3]")#values of specifiations
# <ipython-input-89-32e65d834f5c>:52: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   weights=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[1]")#list of specificaion name
# <ipython-input-89-32e65d834f5c>:53: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   weight_spec=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[3]")#values of specifiations
# <ipython-input-89-32e65d834f5c>:60: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dims=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[1]")#list of specificaion name
# <ipython-input-89-32e65d834f5c>:61: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   dims_spec=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[3]")#values of specifiations
# <ipython-input-89-32e65d834f5c>:67: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   GPUs=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[1]")#list of specificaion name
# <ipython-input-89-32e65d834f5c>:68: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   GPUs_spec=driver.find_elements_by_xpath("//div[@class='Spcs-details']/table/tbody/tr/td[3]")#values of specifiations
# <ipython-input-89-32e65d834f5c>:74: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   urls=driver.find_elements_by_xpath("//div[@class='full-specs']/span")#getting the url of full specs links
# <ipython-input-89-32e65d834f5c>:82: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   prices=driver.find_element_by_xpath("/html/body/div[3]/div[2]/div[3]/div[3]/div[4]/div/h2/strong")
#                           Name      Price               OS  \
# 0                 HP VICTUS 16  ₹ 104,990       WINDOWS 10
# 1                   HP OMEN 15  ₹ 110,790  WINDOWS 10 HOME
# 2                 ACER NITRO 5  ₹ 129,990       WINDOWS 10
# 3              MSI STEALTH 15M  ₹ 134,990       WINDOWS 10
# 4       ASUS ROG STRIX SCAR 15  ₹ 193,990       WINDOWS 10
# 5       ASUS ROG STRIX SCAR 15  ₹ 215,990  WINDOWS 10 HOME
# 6            ASUS ZEPHYRUS G14  ₹ 144,990  WINDOWS 10 HOME
# 7             LENOVO LEGION 5I   ₹ 76,988   WINDOWS 10 PRO
# 8     ASUS ROG ZEPHYRUS DUO 15  ₹ 185,000       WINDOWS 10
# 9  ACER ASPIRE 7 GAMING LAPTOP   ₹ 53,490  WINDOWS 10 HOME
#
#                Display         HDD           RAM weight  \
# 0  16.1" (1920 X 1200)  512 GB SSD  16 GBGB DDR4   2.48
# 1  15.6" (1920 X 1080)    1 TB SSD  16 GBGB DDR4   2.37
# 2  15.6" (1920 X 1080)    1 TB HDD  16 GBGB DDR4    2.4
# 3  15.6" (1920 X 1080)    1 TB SSD  16 GBGB DDR4    1.7
# 4  15.6" (2560 X 1440)    2 TB SSD  32 GBGB DDR4   2.30
# 5  15.6" (1920 X 1080)    1 TB SSD  16 GBGB DDR4   2.30
# 6    14" (1920 X 1080)    1 TB SSD  16 GBGB DDR4   1.65
# 7  15.6" (1920 X 1080)    1 TB SSD  16 GBGB DDR4    2.3
# 8  15.6" (3840 X 1100)  512 GB SSD   4 GBGB DDR4    2.4
# 9  15.6" (1920 X 1080)  512 GB SSD   8 GBGB DDR4   2.15
#
#                  Dimension            Graphical processor
# 0          37 x 26.2 x 2.4        NVIDIA GeForce RTX 3060
# 1     357.9 x 239.7 x 22.5        NVIDIA GeForce RTX 3060
# 2       363.4 x 255 x 23.9        NVIDIA GeForce RTX 3070
# 3      358.3 x 248 x 16.15        NVIDIA GeForce RTX 3060
# 4         354 x 259 x 22.6        NVIDIA GeForce RTX 3080
# 5       35.4 x 25.9 x 2.26      NVIDIA® GeForce RTX™ 3070
# 6        32.5 x 22.1 x 1.8        NVIDIA GeForce RTX 2060
# 7  363.06 x 259.61 x 23.57  NVIDIA® GeForce® GTX 1650 4GB
# 8  268.30 x 360.00 x 20.90  NVIDIA GeForce RTX 2070 Max-Q
# 9       2.29 x 36.3 x 25.4      NVIDIA® GeForce® GTX 1650

# %%
df.to_csv("Best_Gaming_laptops_digit.csv")

# %% [markdown]
# 8- Write a python program to scrape the details for all billionaires from www.forbes.com. Details to be scrapped: “Rank”, “Name”, “Net worth”, “Age”, “Citizenship”, “Source”, “Industry”.

# %%
driver = webdriver.Chrome(r'C:\Users\welcome\Desktop\chromedriver_win32\chromedriver.exe')
# Out:
# <ipython-input-93-53e154298f5b>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\welcome\Desktop\chromedriver_win32\chromedriver.exe')

# %%
url="https://www.forbes.com"
driver.get(url)

# %%
exp= driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[1]/button[1]")
exp.click()
btn= driver.find_element_by_xpath("//li[@class='header__channel header__color--centennial-silver header__hoverable']")
btn.click()
btn1= driver.find_element_by_xpath("/html/body/div[1]/header/nav/div[3]/ul/li[1]/div[2]/ul/li[2]/a")
btn1.click()
nm=driver.find_elements_by_xpath("//div[@class='personName']")
name=[]
for i in nm:
    name.append(i.text)
worth= driver.find_elements_by_xpath("//div[@class='netWorth']")
n_worth=[]
for i in worth:
    n_worth.append(i.text)
citz= driver.find_elements_by_xpath("//div[@class='countryOfCitizenship']")
citzn=[]
for i in citz:
    citzn.append(i.text)
src_t= driver.find_elements_by_xpath("//div[@class='source-column']")
src=[]
for i in src_t:
    src.append(i.text)
rnk_t= driver.find_elements_by_xpath("//div[@class='rank']")
rnk=[]
for i in rnk_t:
    rnk.append(i.text)
billionaires=pd.DataFrame()
billionaires["Rank"]=rnk
billionaires["Name"]=name
billionaires["Citezenship"]=citzn
billionaires["Source"]=src
billionaires.head()

# %% [markdown]
# 9. Write a program to extract at least 500 Comments, Comment upvote and time when comment was posted from any YouTube Video.

# %%
driver = webdriver.Chrome(r'C:\Users\welcome\Desktop\chromedriver_win32\chromedriver.exe')
# Out:
# <ipython-input-103-53e154298f5b>:1: DeprecationWarning: executable_path has been deprecated, please pass in a Service object
#   driver = webdriver.Chrome(r'C:\Users\welcome\Desktop\chromedriver_win32\chromedriver.exe')

# %%
driver.get('https://www.youtube.com')
time.sleep(2)
#driver.find_element_by_xpath('/html/body/ytd-app/div/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/form/div[1]/div[1]/input')
search= driver.find_element_by_xpath("/html/body/ytd-app/div/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/form/div[1]/div[1]/input")
search.send_keys('Hollywood is bleeding')
search_btn = driver.find_element_by_xpath("/html/body/ytd-app/div/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/button/yt-icon")
search_btn.click()
time.sleep(3)
driver.find_element_by_xpath('//a[@class="yt-simple-endpoint style-scope ytd-video-renderer"]').click()
time.sleep(4)
driver.find_element_by_xpath('//button[@class="ytp-play-button ytp-button"]').click()
# Out:
# <ipython-input-104-636c279eb97e>:4: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search= driver.find_element_by_xpath("/html/body/ytd-app/div/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/form/div[1]/div[1]/input")
# <ipython-input-104-636c279eb97e>:6: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   search_btn = driver.find_element_by_xpath("/html/body/ytd-app/div/div/ytd-masthead/div[3]/div[2]/ytd-searchbox/button/yt-icon")
# <ipython-input-104-636c279eb97e>:9: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//a[@class="yt-simple-endpoint style-scope ytd-video-renderer"]').click()
# <ipython-input-104-636c279eb97e>:11: DeprecationWarning: find_element_by_* commands are deprecated. Please use find_element() instead
#   driver.find_element_by_xpath('//button[@class="ytp-play-button ytp-button"]').click()

# %%
for _ in range(0,50):
    driver.execute_script('window.scrollBy(0,50)')
    time.sleep(3)
    driver.execute_script('window.scrollBy(0,-20)')
    time.sleep(1)

# %%
comments = []
upvotes = []
posted_on = []

com = driver.find_elements_by_xpath('//*[@id="content-text"]')
up = driver.find_elements_by_xpath('//*[@id="vote-count-middle"]')
post = driver.find_elements_by_xpath('//*[@id="header-author"]/yt-formatted-string')

for i in com:
    try:
        comments.append(i.text)
    except NoSuchElementException:
        comments.append('NA')
        
for j in up:
    try:
        upvotes.append(j.text)
    except NoSuchElementException:
        upvotes.append('NA')
        
for k in post:
    try:
        posted_on.append(k.text)
    except NoSuchElementException:
        posted_on.append('NA')
# Out:
# <ipython-input-106-8cfea658a685>:5: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   com = driver.find_elements_by_xpath('//*[@id="content-text"]')
# <ipython-input-106-8cfea658a685>:6: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   up = driver.find_elements_by_xpath('//*[@id="vote-count-middle"]')
# <ipython-input-106-8cfea658a685>:7: DeprecationWarning: find_elements_by_* commands are deprecated. Please use find_elements() instead
#   post = driver.find_elements_by_xpath('//*[@id="header-author"]/yt-formatted-string')

# %%
print(len(comments),len(upvotes),len(posted_on))
# Out:
# 20 20 20

# %%
hollywood = pd.DataFrame({})
hollywood['comments'] =comments
hollywood['upvotes'] = upvotes
hollywood['posted_on'] = posted_on
hollywood.head()
# Out:
#                                             comments upvotes      posted_on
# 0  He sounds like he poured all of his heart in t...    8.3K    2 years ago
# 1  The only song I've repeated a million times, a...      2K     1 year ago
# 2  We just gonna ignore that he’s basically expos...      3K  11 months ago
# 3  Post sings the right song in the Grammys, he s...    3.5K  11 months ago
# 4  He sent hollywood a message, now we must prote...    1.1K  11 months ago
